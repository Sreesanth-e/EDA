# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('messy_IMDB_dataset.csv', 'r', encoding='latin1') as f:
    for i in range(10):
        print(f"{i+1}: {f.readline()}")
# Out:
# 1: IMBD title ID;Original titlÊ;Release year;Genrë¨;Duration;Country;Content Rating;Director;;Income; Votes ;Score
#
# 2: tt0111161;The Shawshank Redemption;1995-02-10;Drama;142;USA;R;Frank Darabont;;$ 28815245;2.278.845;9.3
#
# 3: tt0068646;The Godfather;09 21 1972;Crime, Drama;175;USA;R;Francis Ford Coppola;;$ 246120974;1.572.674;9.2
#
# 4: tt0468569;The Dark Knight; 23 -07-2008;Action, Crime, Drama;152;US;PG-13;Christopher Nolan;;$ 1005455211;2.241.615;9.
#
# 5: tt0071562;The Godfather: Part II;1975-09-25;Crime, Drama;220;USA;R;Francis Ford Coppola;;$ 4o8,035,783;1.098.714;9,.0
#
# 6: tt0110912;Pulp Fiction;1994-10-28;Crime, Drama; ;USA;R;Quentin Tarantino;;$ 222831817;1.780.147;8,9f
#
# 7: tt0167260;The Lord of the Rings: The Return of the King;22 Feb 04;Action, Adventure, Drama;201;New Zealand;PG-13;Peter Jackson;;$ 1142271098;1.604.280;08.9
#
# 8: tt0108052;Schindler's List;1994-03-11;Biography, Drama, History;Nan;USA;R;Steven Spielberg;;$ 322287794;1.183.248;8.9
#
# ...

# %%
data = pd.read_csv(
    'messy_IMDB_dataset.csv',
    sep=';',
    encoding='latin1'
)

# %%
data.head()
# Out:
#   IMBD title ID            Original titlÊ  Release year                Genrë¨  \
# 0     tt0111161  The Shawshank Redemption    1995-02-10                 Drama
# 1     tt0068646             The Godfather    09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight   23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II    1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction    1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director  Unnamed: 8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# 2      152      US          PG-13     Christopher Nolan         NaN
# 3      220     USA              R  Francis Ford Coppola         NaN
# 4              USA              R     Quentin Tarantino         NaN
#
#           Income     Votes  Score
# 0     $ 28815245  2.278.845   9.3
# ...

# %%
data.isna().sum()
# Out:
# IMBD title ID       1
# Original titlÊ      1
# Release year        1
# Genrë¨              1
# Duration            2
# Country             1
# Content Rating     24
# Director            1
# Unnamed: 8        101
# Income              1
#  Votes              1
# Score               1
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.columns
# Out:
# Index(['IMBD title ID', 'Original titlÊ', 'Release year', 'Genrë¨', 'Duration',
#        'Country', 'Content Rating', 'Director', 'Unnamed: 8', 'Income',
#        ' Votes ', 'Score'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IMBD title ID   100 non-null    object
#  1   Original titlÊ  100 non-null    object
#  2   Release year    100 non-null    object
#  3   Genrë¨          100 non-null    object
#  4   Duration        99 non-null     object
#  5   Country         100 non-null    object
#  6   Content Rating  77 non-null     object
#  7   Director        100 non-null    object
#  8   Unnamed: 8      0 non-null      float64
#  9   Income          100 non-null    object
#  10   Votes          100 non-null    object
#  11  Score           100 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 9.6+ KB

# %%
data['Unnamed: 8']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 96    NaN
# 97    NaN
# 98    NaN
# 99    NaN
# 100   NaN
# Name: Unnamed: 8, Length: 101, dtype: float64

# %%
data = data.drop(columns='Unnamed: 8')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IMBD title ID   100 non-null    object
#  1   Original titlÊ  100 non-null    object
#  2   Release year    100 non-null    object
#  3   Genrë¨          100 non-null    object
#  4   Duration        99 non-null     object
#  5   Country         100 non-null    object
#  6   Content Rating  77 non-null     object
#  7   Director        100 non-null    object
#  8   Income          100 non-null    object
#  9    Votes          100 non-null    object
#  10  Score           100 non-null    object
# dtypes: object(11)
# memory usage: 8.8+ KB

# %%
data.head()
# Out:
#   IMBD title ID            Original titlÊ  Release year                Genrë¨  \
# 0     tt0111161  The Shawshank Redemption    1995-02-10                 Drama
# 1     tt0068646             The Godfather    09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight   23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II    1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction    1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director         Income  \
# 0      142     USA              R        Frank Darabont     $ 28815245
# 1      175     USA              R  Francis Ford Coppola    $ 246120974
# 2      152      US          PG-13     Christopher Nolan   $ 1005455211
# 3      220     USA              R  Francis Ford Coppola  $ 4o8,035,783
# 4              USA              R     Quentin Tarantino    $ 222831817
#
#       Votes  Score
# 0  2.278.845   9.3
# 1  1.572.674   9.2
# ...

# %%
data.isna().sum()
# Out:
# IMBD title ID      1
# Original titlÊ     1
# Release year       1
# Genrë¨             1
# Duration           2
# Country            1
# Content Rating    24
# Director           1
# Income             1
#  Votes             1
# Score              1
# dtype: int64

# %%
for col in data:
    print(data[col].unique())
# Out:
# ['tt0111161' 'tt0068646' 'tt0468569' 'tt0071562' 'tt0110912' 'tt0167260'
#  'tt0108052' 'tt0050083' 'tt1375666' 'tt0137523' 'tt0109830' 'tt0120737'
#  'tt0060196' nan 'tt0133093' 'tt0167261' 'tt0080684' 'tt0099685'
#  'tt0073486' 'tt0816692' 'tt0114369' 'tt0102926' 'tt0076759' 'tt0120815'
#  'tt0120689' 'tt0317248' 'tt0245429' 'tt0118799' 'tt6751668' 'tt0038650'
#  'tt0047478' 'tt0172495' 'tt0407887' 'tt0482571' 'tt0088763' 'tt0120586'
#  'tt0110413' 'tt0103064' 'tt0114814' 'tt0110357' 'tt7286456' 'tt1675434'
#  'tt0253474' 'tt2582802' 'tt0054215' 'tt0034583' 'tt0064116' 'tt0095327'
#  'tt0095765' 'tt0027977' 'tt1345836' 'tt1853728' 'tt0209144' 'tt0910970'
#  'tt0081505' 'tt0082971' 'tt4154756' 'tt0078748' 'tt4154796' 'tt0078788'
#  'tt0364569' 'tt0057012' 'tt0047396' 'tt2380307' 'tt0405094' 'tt4633694'
#  'tt1187043' 'tt0119698' 'tt0087843' 'tt0032553' 'tt0043014' 'tt0361748'
#  'tt0169547' 'tt0112573' 'tt0086190' 'tt0105236' 'tt0338013' 'tt0114709'
# ...

# %% [markdown]
# - titleId - it has one missing values and the uniquq colum also looks good just adjust the white spaces
# - Original Title - need to chanhge the column nname and has ine missing value and standardized the text
# - release year - need to change the data time data type and there few inapproaitate terms before changin handle them
#     either drop them or change their format by using regex
# - genre - remove white spaces and standarize the name drop that one null or fill with mode
# - duration - has inf , - and c suffix and spaces remove those null values are 2
# - country - it has different format of same country and few spelling mistakes handle them
# - Content rating - R' 'PG-13' 'Not Rated' 'Approved' nan 'PG' 'Unrated' 'G' handle just those null values
# - director - remoce white spaces and handle them, to standardiezed
# - Income - make sure you that it is in proper numeric format like there is o instead of 0 handle the missing values
# - votes - it is not proper format of float
# - score - it has different symbol and double .. so handle them few thery re starting with 08 and i see two ++ symbols

# %%
df = data.copy()

# %%
df.head()
# Out:
#   IMBD title ID            Original titlÊ  Release year                Genrë¨  \
# 0     tt0111161  The Shawshank Redemption    1995-02-10                 Drama
# 1     tt0068646             The Godfather    09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight   23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II    1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction    1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director         Income  \
# 0      142     USA              R        Frank Darabont     $ 28815245
# 1      175     USA              R  Francis Ford Coppola    $ 246120974
# 2      152      US          PG-13     Christopher Nolan   $ 1005455211
# 3      220     USA              R  Francis Ford Coppola  $ 4o8,035,783
# 4              USA              R     Quentin Tarantino    $ 222831817
#
#       Votes  Score
# 0  2.278.845   9.3
# 1  1.572.674   9.2
# ...

# %% [markdown]
# titleId - it has one missing values and the uniquq colum also looks good just adjust the white spaces

# %%
df['IMBD title ID'].isna().sum()
# Out:
# np.int64(1)

# %%
df[df['IMBD title ID'].isna()]
# Out:
#    IMBD title ID Original titlÊ Release year Genrë¨ Duration Country  \
# 13           NaN            NaN          NaN    NaN      NaN     NaN
#
#    Content Rating Director Income  Votes  Score
# 13            NaN      NaN    NaN     NaN   NaN

# %%
df = df.dropna(subset='IMBD title ID')
df['IMBD title ID'].isna().sum()
# Out:
# np.int64(0)

# %%
df[df['IMBD title ID'].isna()]
# Out:
# Empty DataFrame
# Columns: [IMBD title ID, Original titlÊ, Release year, Genrë¨, Duration, Country, Content Rating, Director, Income,  Votes , Score]
# Index: []

# %%
df['IMBD title ID'] = df['IMBD title ID'].str.strip()

# %% [markdown]
# Original Title - need to chanhge the column nname and has missing value and standardized the text

# %%
df = df.rename(columns ={"Original titlÊ" : "Original Title"})

# %%
df.isna().sum()
# Out:
# IMBD title ID      0
# Original Title     0
# Release year       0
# Genrë¨             0
# Duration           1
# Country            0
# Content Rating    23
# Director           0
# Income             0
#  Votes             0
# Score              0
# dtype: int64

# %%
df['Original Title'] = df['Original Title'].str.strip()

# %%
df['Original Title'].unique()
# Out:
# array(['The Shawshank Redemption', 'The Godfather', 'The Dark Knight',
#        'The Godfather: Part II', 'Pulp Fiction',
#        'The Lord of the Rings: The Return of the King',
#        "Schindler's List", '12 Angry Men', 'Inception', 'Fight Club',
#        'Forrest Gump',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'Il buono, il brutto, il cattivo', 'The Matrix',
#        'The Lord of the Rings: The Two Towers',
#        'Star Wars: Episode V - The Empire Strikes Back', 'Goodfellas',
#        "One Flew Over the Cuckoo's Nest", 'Interstellar', 'Se7en',
#        'The Silence of the Lambs', 'Star Wars', 'Saving Private Ryan',
#        'The Green Mile', 'Cidade de Deus',
#        'Sen to Chihiro no kamikakushi', 'La vita B9 bella',
#        'Gisaengchung', "It's a Wonderful Life", 'Shichinin no samurai',
#        'Gladiator', 'The Departed', 'The Prestige', 'Back to the Future',
#        'American History X', 'LÃ©on', 'Terminator 2: Judgment Day',
# ...

# %% [markdown]
# release year - need to change the data time data type and there few inapproaitate terms before changin handle them
#     either drop them or change their format by using regex

# %%
# df['Release year'] = pd.to_datetime(df['Release year'])

# %%
df['Release year'].unique()
# Out:
# array(['1995-02-10', '09 21 1972', ' 23 -07-2008', '1975-09-25',
#        '1994-10-28', '22 Feb 04', '1994-03-11', '1957-09-04',
#        '2010-09-24', '10-29-99', '1994-10-06', '2002-01-18',
#        '23rd December of 1966 ', '1999-05-07', '01/16-03', '1980-09-19',
#        '1990-09-20', '18/11/1976', '2014-11-06', '1995-12-15',
#        '1991-03-05', '1977-10-20', '1998-10-30', '2000-10-03',
#        '2003-05-09', '2003-04-18', '1997-12-20', '2019-11-07',
#        '1948-03-11', '1955-08-19', '2000-05-19', '2006-10-27',
#        '2006-12-22', '1985-10-18', '1999-08-27', '1995-04-07',
#        '1991-12-19', '1995-11-30', '1994-11-25', '2019-10-03',
#        '2012-02-24', '2002-10-25', '2015-02-12', '1960-10-28', '21-11-46',
#        '1968-12-21', '2015-10-11', '1988-11-17', '1937-03-12',
#        '2012-08-29', '2013-01-17', '2001-01-19', '2008-10-17',
#        '1980-12-22', '1981-06-12', '2018-04-25', '1979-10-25',
#        '2019-04-24', '1979-12-18', '2005-05-06', '1964-04-03',
# ...

# %%
small_data ={ "Date" : ["The 6th of marco, year 1951","23 -07-2008","23rd December of 1966","22 Feb 04","2011-10-21" , "21-11-46" , "01/16-03","22 Feb 04","23rd December of 1966",]}
df_new = pd.DataFrame(small_data)

# %%
df_new
# Out:
#                           Date
# 0  The 6th of marco, year 1951
# 1                  23 -07-2008
# 2        23rd December of 1966
# 3                    22 Feb 04
# 4                   2011-10-21
# 5                     21-11-46
# 6                     01/16-03
# 7                    22 Feb 04
# 8        23rd December of 1966

# %%
from dateutil.parser import parse

# %%
from calendar import monthrange
df_new = df_new["Date"].apply( lambda x : parse(x ,fuzzy=True) )
s = "1984-02-34"
parts = s.split("-")
print(parts)
# Out:
# ['1984', '02', '34']

# %%
from datetime import datetime


def fix_country(d):
    if pd.isna(d):
        return d
    if d.year > datetime.now().year:
        d = d.replace(year = d.year - 100)
    return d

# %%
df_new = df_new.apply(fix_country)

# %%
df_new
# Out:
# 0   1951-06-17
# 1   2008-07-23
# 2   1966-12-23
# 3   2004-02-22
# 4   2011-10-21
# 5   1946-11-21
# 6   2003-01-16
# 7   2004-02-22
# 8   1966-12-23
# Name: Date, dtype: datetime64[ns]

# %%
def safe_parse(s):
    try:
        return parse(s,fuzzy=True)
    except(ValueError,OverflowError):
        return pd.NaT

# %%
df["Release year"] = df["Release year"].apply(safe_parse)
df["Release year"] = df["Release year"].apply(fix_country)

# %%
df["Release year"].unique()
# Out:
# <DatetimeArray>
# ['1995-02-10 00:00:00', '1972-09-21 00:00:00', '2008-07-23 00:00:00',
#  '1975-09-25 00:00:00', '1994-10-28 00:00:00', '2004-02-22 00:00:00',
#  '1994-03-11 00:00:00', '1957-09-04 00:00:00', '2010-09-24 00:00:00',
#  '1999-10-29 00:00:00', '1994-10-06 00:00:00', '2002-01-18 00:00:00',
#  '1966-12-23 00:00:00', '1999-05-07 00:00:00', '2003-01-16 00:00:00',
#  '1980-09-19 00:00:00', '1990-09-20 00:00:00', '1976-11-18 00:00:00',
#  '2014-11-06 00:00:00', '1995-12-15 00:00:00', '1991-03-05 00:00:00',
#  '1977-10-20 00:00:00', '1998-10-30 00:00:00', '2000-10-03 00:00:00',
#  '2003-05-09 00:00:00', '2003-04-18 00:00:00', '1997-12-20 00:00:00',
#  '2019-11-07 00:00:00', '1948-03-11 00:00:00', '1955-08-19 00:00:00',
#  '2000-05-19 00:00:00', '2006-10-27 00:00:00', '2006-12-22 00:00:00',
#  '1985-10-18 00:00:00', '1999-08-27 00:00:00', '1995-04-07 00:00:00',
#  '1991-12-19 00:00:00', '1995-11-30 00:00:00', '1994-11-25 00:00:00',
# ...

# %%
df[df['Release year'].isna()]
# Out:
#    IMBD title ID Original Title Release year        Genrë¨ Duration Country  \
# 83     tt0086250       Scarface          NaT  Crime, Drama      170     USA
# 84     tt0075314    Taxi Driver          NaT  Crime, Drama      114     USA
#
#    Content Rating         Director      Income   Votes  Score
# 83              R   Brian De Palma  $ 66023585  721.343   7.8
# 84              R  Martin Scorsese  $ 28441292  703.264   7.7

# %% [markdown]
# genre - remove white spaces and standarize the name drop that one null or fill with mode

# %%
df.columns
# Out:
# Index(['IMBD title ID', 'Original Title', 'Release year', 'Genrë¨', 'Duration',
#        'Country', 'Content Rating', 'Director', 'Income', ' Votes ', 'Score'],
#       dtype='object')

# %%
df = df.rename(columns={'Genrë¨': 'Genre'})

# %%
df.columns
# Out:
# Index(['IMBD title ID', 'Original Title', 'Release year', 'Genre', 'Duration',
#        'Country', 'Content Rating', 'Director', 'Income', ' Votes ', 'Score'],
#       dtype='object')

# %%
df['Genre'] = df['Genre'].str.strip()

# %%
df['Genre'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# duration - has inf , - and c suffix and spaces remove those null values are 2

# %%
df['Duration'].unique()
# df['Duration'] = df['Duration'].str.strip()
# Out:
# array(['142', '175', '152', '220', ' ', '201', 'Nan', '96', '148', 'Inf',
#        '178c', '161', nan, '179', 'Not Applicable', '146', '-', '169',
#        '127', '118', '121', '189', '130', '125', '116', '132', '207',
#        '155', '151', '119', '110', '137', '106', '88', '122', '112',
#        '150', '109', '102', '165', '89', '87', '164', '113', '98', '115',
#        '149', '117', '181', '147', '120', '95', '105', '170', '134',
#        '229', '153', '178', '131', '99', '108', '81', '126', '104', '136',
#        '103', '114', '160', '128', '228', '129', '123'], dtype=object)

# %%
df['Duration'] = df['Duration'].replace(['Not Applicable',' ','-','Inf','Nan'] , np.nan)

# %%
df['Duration'] = df['Duration'].str.replace('c' , '')
df['Duration'].unique()
# Out:
# array(['142', '175', '152', '220', nan, '201', '96', '148', '178', '161',
#        '179', '146', '169', '127', '118', '121', '189', '130', '125',
#        '116', '132', '207', '155', '151', '119', '110', '137', '106',
#        '88', '122', '112', '150', '109', '102', '165', '89', '87', '164',
#        '113', '98', '115', '149', '117', '181', '147', '120', '95', '105',
#        '170', '134', '229', '153', '131', '99', '108', '81', '126', '104',
#        '136', '103', '114', '160', '128', '228', '129', '123'],
#       dtype=object)

# %%
df['Duration'].isna().sum()
# Out:
# np.int64(6)

# %%
df[df['Duration'].isna()]
# Out:
#    IMBD title ID                                  Original Title Release year  \
# 4      tt0110912                                    Pulp Fiction   1994-10-28
# 6      tt0108052                                Schindler's List   1994-03-11
# 9      tt0137523                                      Fight Club   1999-10-29
# 14     tt0133093                                      The Matrix   1999-05-07
# 16     tt0080684  Star Wars: Episode V - The Empire Strikes Back   1980-09-19
# 18     tt0073486                 One Flew Over the Cuckoo's Nest   1976-11-18
#
#                          Genre Duration Country Content Rating  \
# 4                 Crime, Drama      NaN     USA              R
# 6    Biography, Drama, History      NaN     USA              R
# 9                        Drama      NaN      UK              R
# 14              Action, Sci-Fi      NaN     USA              R
# 16  Action, Adventure, Fantasy      NaN     USA             PG
# ...

# %%
df[df['Duration'].isna()]
# Out:
#    IMBD title ID                                  Original Title Release year  \
# 4      tt0110912                                    Pulp Fiction   1994-10-28
# 6      tt0108052                                Schindler's List   1994-03-11
# 9      tt0137523                                      Fight Club   1999-10-29
# 14     tt0133093                                      The Matrix   1999-05-07
# 16     tt0080684  Star Wars: Episode V - The Empire Strikes Back   1980-09-19
# 18     tt0073486                 One Flew Over the Cuckoo's Nest   1976-11-18
#
#                          Genre Duration Country Content Rating  \
# 4                 Crime, Drama      NaN     USA              R
# 6    Biography, Drama, History      NaN     USA              R
# 9                        Drama      NaN      UK              R
# 14              Action, Sci-Fi      NaN     USA              R
# 16  Action, Adventure, Fantasy      NaN     USA             PG
# ...

# %%
df['Duration'] = pd.to_numeric(df['Duration'],errors='coerce')
df['Duration'] = df['Duration'].fillna(df['Duration'].median())
df['Duration'] = df['Duration'].astype('int')

df[df['Duration'].isna()]
# Out:
# Empty DataFrame
# Columns: [IMBD title ID, Original Title, Release year, Genre, Duration, Country, Content Rating, Director, Income,  Votes , Score]
# Index: []

# %%
df['Duration'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# country - it has different format of same country and few spelling mistakes handle them

# %%
df['Country'].unique()
df['Country'].value_counts()
# Out:
# Country
# USA             62
# UK              12
# Italy            4
# Japan            4
# France           3
# South Korea      2
# Germany          2
# New Zesland      1
# New Zealand      1
# New Zeland       1
# US.              1
# Brazil           1
# US               1
# Italy1           1
# India            1
# Denmark          1
# West Germany     1
# Iran             1
# Name: count, dtype: int64

# %%
fixes = {
    'New Zesland' : 'New Zealand',
    'New Zeland' : 'New Zealand',
    'US.' : 'USA',
    'US': 'USA',
    'Italy1' : 'Italy'
}

df['Country'] = df['Country'].replace(fixes)

# %%
df['Country'].unique()
# Out:
# array(['USA', 'New Zealand', 'UK', 'Italy', 'Brazil', 'Japan',
#        'South Korea', 'France', 'Germany', 'India', 'Denmark',
#        'West Germany', 'Iran'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# Country
# USA             64
# UK              12
# Italy            5
# Japan            4
# New Zealand      3
# France           3
# South Korea      2
# Germany          2
# Brazil           1
# India            1
# Denmark          1
# West Germany     1
# Iran             1
# Name: count, dtype: int64

# %%
df['Country'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Content rating - R' 'PG-13' 'Not Rated' 'Approved' nan 'PG' 'Unrated' 'G' handle just those null values

# %%
df['Content Rating'].unique()
# Out:
# array(['R', 'PG-13', 'Not Rated', 'Approved', 'PG', nan, 'Unrated', 'G'],
#       dtype=object)

# %%
df[df['Content Rating'].isna()]
# Out:
#     IMBD title ID                     Original Title Release year  \
# 27      tt0118799                   La vita B9 bella   1997-12-20
# 28      tt6751668                       Gisaengchung   2019-11-07
# 36      tt0110413                              LÃ©on   1995-04-07
# 40      tt7286456                              Joker   2019-10-03
# 41      tt1675434                       Intouchables   2012-02-24
# 47      tt0095327                     Hotaru no haka   2015-10-11
# 48      tt0095765              Nuovo Cinema Paradiso   1988-11-17
# 56      tt4154756             Avengers: Infinity War   2018-04-25
# 58      tt4154796                  Avengers: Endgame   2019-04-24
# 62      tt0047396                        Rear Window   1955-04-14
# 63      tt2380307                               Coco   2017-12-28
# 65      tt4633694  Spider-Man: Into the Spider-Verse   2018-12-25
# 66      tt1187043                           3 Idiots   2009-12-25
# ...

# %%
df['Content Rating'] = df['Content Rating'].fillna('Not Rated')

# %%
df['Content Rating'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# director - remoce white spaces and handle them, to standardiezed

# %%
df['Director'].unique()
# Out:
# array(['Frank Darabont', 'Francis Ford Coppola', 'Christopher Nolan',
#        'Quentin Tarantino', 'Peter Jackson', 'Steven Spielberg',
#        'Sidney Lumet', 'David Fincher', 'Robert Zemeckis', 'Sergio Leone',
#        'Lana Wachowski, Lilly Wachowski', 'Irvin Kershner',
#        'Martin Scorsese', 'Milos Forman', 'Jonathan Demme',
#        'George Lucas', 'Fernando Meirelles, KÃ¡tia Lund',
#        'Hayao Miyazaki', 'Roberto Benigni', 'Bong Joon Ho', 'Frank Capra',
#        'Akira Kurosawa', 'Ridley Scott', 'Tony Kaye', 'Luc Besson',
#        'James Cameron', 'Bryan Singer', 'Roger Allers, Rob Minkoff',
#        'Todd Phillips', 'Olivier Nakache, Ã\x89ric Toledano',
#        'Roman Polanski', 'Damien Chazelle', 'Alfred Hitchcock',
#        'Michael Curtiz', 'Isao Takahata', 'Giuseppe Tornatore',
#        'Charles Chaplin', 'Andrew Stanton', 'Stanley Kubrick',
#        'Anthony Russo, Joe Russo', 'Chan-wook Park',
# ...

# %%
#fixes_director_name= {
#    'Fernando Meirelles, KÃ¡tia Lund' : 'Fernando Meirelles, kaitia Lund',
 #   'Olivier Nakache, Ã\x89ric Toledano' : 'Olivier Nakache, Eric Toledano'
#}
#df['Director'] = df['Director'].replace(fixes_director_name)


# this version only works for few character in order if you have many values it will turn down

# %%
def fix_special(s):
    if pd.isna(s):
        return s
    try:
        return s.encode('latin1').decode('utf-8')
    except(UnicodeDecodeError,UnicodeEncodeError):
        return s

# %%
df_lund = {"data" :["KÃ¡tia Lund","Ã\x89ric Toledano"]}
df_lund_data = pd.DataFrame(df_lund)

# %%
import unicodedata
df_lund_data = df_lund_data["data"].apply(fix_special)

# %%
df_lund_data
# Out:
# 0       Kátia Lund
# 1    Éric Toledano
# Name: data, dtype: object

# %%
df['Director'] = df['Director'].apply(fix_special)

# %%
df['Director'].unique()
# Out:
# array(['Frank Darabont', 'Francis Ford Coppola', 'Christopher Nolan',
#        'Quentin Tarantino', 'Peter Jackson', 'Steven Spielberg',
#        'Sidney Lumet', 'David Fincher', 'Robert Zemeckis', 'Sergio Leone',
#        'Lana Wachowski, Lilly Wachowski', 'Irvin Kershner',
#        'Martin Scorsese', 'Milos Forman', 'Jonathan Demme',
#        'George Lucas', 'Fernando Meirelles, Kátia Lund', 'Hayao Miyazaki',
#        'Roberto Benigni', 'Bong Joon Ho', 'Frank Capra', 'Akira Kurosawa',
#        'Ridley Scott', 'Tony Kaye', 'Luc Besson', 'James Cameron',
#        'Bryan Singer', 'Roger Allers, Rob Minkoff', 'Todd Phillips',
#        'Olivier Nakache, Éric Toledano', 'Roman Polanski',
#        'Damien Chazelle', 'Alfred Hitchcock', 'Michael Curtiz',
#        'Isao Takahata', 'Giuseppe Tornatore', 'Charles Chaplin',
#        'Andrew Stanton', 'Stanley Kubrick', 'Anthony Russo, Joe Russo',
#        'Chan-wook Park', 'Lee Unkrich, Adrian Molina',
# ...

# %%
print(df[df['Director'].str.contains('Lund', na=False)]['Director'].tolist())
# Out:
# ['Fernando Meirelles, Kátia Lund']

# %%
print(df[df['Director'].str.contains('Toledano', na=False)]['Director'].tolist())
# Out:
# ['Olivier Nakache, Éric Toledano']

# %%
df['Director'] =  df['Director'].str.strip()

# %% [markdown]
# Income - make sure you that it is in proper numeric format like there is o instead of 0 handle the missing values

# %%
df['Income'].unique()
# Out:
# array(['$ 28815245', '$ 246120974', '$ 1005455211', '$ 4o8,035,783',
#        '$ 222831817', '$ 1142271098', '$ 322287794', '$ 576',
#        '$ 869784991', '$ 101218804', '$ 678229452', '$ 887934303',
#        '$ 25252481', '$ 465718588', '$ 951227416', '$ 549265501',
#        '$ 46879633', '$ 108997629', '$ 696742056', '$ 327333559',
#        '$ 272753884', '$ 775768912', '$ 482349603', '$ 286801374',
#        '$ 30680793', '$ 355467056', '$ 230098753', '$ 257604912',
#        '$ 6130720', '$ 322773', '$ 465361176', '$ 291465034',
#        '$ 109676311', '$ 388774684', '$ 23875127', '$ 19552639',
#        '$ 520884847', '$ 23341568', '$ 968511805', '$ 1074251311',
#        '$ 426588510', '$ 120072577', '$ 48983260', '$ 32008644',
#        '$ 4374761', '$ 112911', '$ 516962', '$ 13826605', '$ 457688',
#        '$ 1081133191', '$ 425368238', '$ 39970386', '$ 521311860',
#        '$ 46520613', '$ 390133212', '$ 2048359754', '$ 108110316',
# ...

# %%
df['Income'] = df['Income'].str.replace('o' , '0')

# %%
df['Income'].unique()
# Out:
# array(['$ 28815245', '$ 246120974', '$ 1005455211', '$ 408,035,783',
#        '$ 222831817', '$ 1142271098', '$ 322287794', '$ 576',
#        '$ 869784991', '$ 101218804', '$ 678229452', '$ 887934303',
#        '$ 25252481', '$ 465718588', '$ 951227416', '$ 549265501',
#        '$ 46879633', '$ 108997629', '$ 696742056', '$ 327333559',
#        '$ 272753884', '$ 775768912', '$ 482349603', '$ 286801374',
#        '$ 30680793', '$ 355467056', '$ 230098753', '$ 257604912',
#        '$ 6130720', '$ 322773', '$ 465361176', '$ 291465034',
#        '$ 109676311', '$ 388774684', '$ 23875127', '$ 19552639',
#        '$ 520884847', '$ 23341568', '$ 968511805', '$ 1074251311',
#        '$ 426588510', '$ 120072577', '$ 48983260', '$ 32008644',
#        '$ 4374761', '$ 112911', '$ 516962', '$ 13826605', '$ 457688',
#        '$ 1081133191', '$ 425368238', '$ 39970386', '$ 521311860',
#        '$ 46520613', '$ 390133212', '$ 2048359754', '$ 108110316',
# ...

# %%
df['Income'] =df['Income'].str.replace('$' , '')

# %%
df['Income'] =df['Income'].str.replace(',' , '')

# %%
df['Income']
# Out:
# 0         28815245
# 1        246120974
# 2       1005455211
# 3        408035783
# 4        222831817
#           ...
# 96       156000000
# 97        11487676
# 98        15000000
# 99        22926076
# 100        1864182
# Name: Income, Length: 100, dtype: object

# %%
df['Income'] = df['Income'].astype('int')

# %%
df['Income'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# votes - it is not proper format of float

# %%
df[' Votes '].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# IMBD title ID     0
# Original Title    0
# Release year      2
# Genre             0
# Duration          0
# Country           0
# Content Rating    0
# Director          0
# Income            0
#  Votes            0
# Score             0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
df['Votes'] = df['Votes'].str.replace('.','')

# %%
df['Votes'] = df['Votes'].astype('int')

# %%
df['Votes'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# score - it has different symbol and double .. so handle them few thery re starting with 08 and i see two ++ symbols

# %%
df['Score'].unique()
# Out:
# array(['9.3', '9.2', '9.', '9,.0', '8,9f', '08.9', '8.9', '8..8', '8.8',
#        '8:8', '++8.7', '8.7.', '8,7e-0', '8.7', '8.6', '8,6', '8.5',
#        '8.4', '8.3', '8.2', '8.1', '8.0', '7.9', '7.8', '7.7', '7.6',
#        '7.5', '7.4'], dtype=object)

# %%
df['Score'] = df['Score'].str.replace(r'[.,:]' , '', regex=True)

# %%
df['Score'].unique()
# Out:
# array(['93', '92', '9', '90', '89f', '089', '89', '88', '++87', '87',
#        '87e-0', '86', '85', '84', '83', '82', '81', '80', '79', '78',
#        '77', '76', '75', '74'], dtype=object)

# %%
df['Score'] = df['Score'].str.lstrip('0')

# %%
df['Score'].unique()
# Out:
# array(['93', '92', '9', '90', '89f', '89', '88', '++87', '87', '87e-0',
#        '86', '85', '84', '83', '82', '81', '80', '79', '78', '77', '76',
#        '75', '74'], dtype=object)

# %%
import re
def clean_score(s):

    if pd.isna(s):
        return s
    digits = re.sub(r'\D' , '', str(s))
    interger_part = digits[0]
    float_part = digits[1:] if len(digits) > 1 else '0'
    return float(f"{interger_part}.{float_part}")

# %%
df['Score'] = df['Score'].apply(clean_score)

# %%
df['Score'].unique()
# Out:
# array([9.3, 9.2, 9. , 8.9, 8.8, 8.7, 8.6, 8.5, 8.4, 8.3, 8.2, 8.1, 8. ,
#        7.9, 7.8, 7.7, 7.6, 7.5, 7.4])

# %%
df['Score'].dtype
# Out:
# dtype('float64')

# %%
df.isna().sum()
# Out:
# IMBD title ID     0
# Original Title    0
# Release year      2
# Genre             0
# Duration          0
# Country           0
# Content Rating    0
# Director          0
# Income            0
# Votes             0
# Score             0
# dtype: int64

# %%
df = df.dropna(subset='Release year')

# %%
df.isna().sum()
# Out:
# IMBD title ID     0
# Original Title    0
# Release year      0
# Genre             0
# Duration          0
# Country           0
# Content Rating    0
# Director          0
# Income            0
# Votes             0
# Score             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IMBD title ID   98 non-null     object
#  1   Original Title  98 non-null     object
#  2   Release year    98 non-null     datetime64[ns]
#  3   Genre           98 non-null     object
#  4   Duration        98 non-null     int64
#  5   Country         98 non-null     object
#  6   Content Rating  98 non-null     object
#  7   Director        98 non-null     object
#  8   Income          98 non-null     int64
#  9   Votes           98 non-null     int64
#  10  Score           98 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 9.2+ KB

# %%
df['Content Rating'].unique()
# Out:
# array(['R', 'PG-13', 'Not Rated', 'Approved', 'PG', 'Unrated', 'G'],
#       dtype=object)

# %%
df['IMBD title ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#     IMBD title ID               Original Title Release year  \
# 0       tt0111161     The Shawshank Redemption   1995-02-10
# 1       tt0068646                The Godfather   1972-09-21
# 2       tt0468569              The Dark Knight   2008-07-23
# 3       tt0071562       The Godfather: Part II   1975-09-25
# 4       tt0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...
# 96      tt0070735                    The Sting   1974-03-21
# 97      tt0082096                     Das Boot   1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹   1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin   2011-10-21
# 100     tt0045152          Singin' in the Rain   1953-02-05
#
#                           Genre  Duration       Country Content Rating  \
# 0                         Drama       142           USA              R
# 1                  Crime, Drama       175           USA              R
# ...

# %%
df.to_csv('Cleaned_IMDB_data.csv' , index= False)

# %%
df['Score'].head(10).tolist()
# Out:
# [9.3, 9.2, 9.0, 9.0, 8.9, 8.9, 8.9, 8.9, 8.8, 8.8]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IMBD title ID   98 non-null     object
#  1   Original Title  98 non-null     object
#  2   Release year    98 non-null     datetime64[ns]
#  3   Genre           98 non-null     object
#  4   Duration        98 non-null     int64
#  5   Country         98 non-null     object
#  6   Content Rating  98 non-null     object
#  7   Director        98 non-null     object
#  8   Income          98 non-null     int64
#  9   Votes           98 non-null     int64
#  10  Score           98 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 9.2+ KB

# %%
df
# Out:
#     IMBD title ID               Original Title Release year  \
# 0       tt0111161     The Shawshank Redemption   1995-02-10
# 1       tt0068646                The Godfather   1972-09-21
# 2       tt0468569              The Dark Knight   2008-07-23
# 3       tt0071562       The Godfather: Part II   1975-09-25
# 4       tt0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...
# 96      tt0070735                    The Sting   1974-03-21
# 97      tt0082096                     Das Boot   1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹   1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin   2011-10-21
# 100     tt0045152          Singin' in the Rain   1953-02-05
#
#                           Genre  Duration       Country Content Rating  \
# 0                         Drama       142           USA              R
# 1                  Crime, Drama       175           USA              R
# ...

# %%
df.describe()
# Out:
#                         Release year    Duration        Income         Votes  \
# count                             98   98.000000  9.800000e+01  9.800000e+01
# mean   1990-09-08 14:41:37.959183616  134.826531  3.042662e+08  8.321686e+05
# min              1937-03-12 00:00:00   81.000000  5.760000e+02  1.957890e+05
# 25%              1978-04-21 18:00:00  115.250000  2.347496e+07  3.885630e+05
# 50%              1995-11-30 12:00:00  129.000000  1.148744e+08  7.606875e+05
# 75%              2005-03-18 00:00:00  149.750000  4.070932e+08  1.108972e+06
# max              2020-01-23 00:00:00  229.000000  2.797801e+09  2.278845e+06
# std                              NaN   30.435677  4.389796e+08  4.875880e+05
#
#            Score
# count  98.000000
# mean    8.250000
# min     7.400000
# 25%     7.900000
# 50%     8.300000
# 75%     8.600000
# max     9.300000
# std     0.450487

# %%
df.columns
# Out:
# Index(['IMBD title ID', 'Original Title', 'Release year', 'Genre', 'Duration',
#        'Country', 'Content Rating', 'Director', 'Income', 'Votes', 'Score'],
#       dtype='object')

# %% [markdown]
# 1. Univariate :
#     - chech which year haas many movies
#     - WHich genre are many
#     - Country which country has many movies
#     - WHich is teh director
# 2. Bivarirate :
#     - Which year genrated more income
#     - Which genre created more income
#     - which genre has more duration
#     - is there any relation between Duration and Income
#     - which director created more income
#     - Did content rating effect the Income
#     - Which country created more number of income
#     - Which movie has more votes
# 3. multi variate :
#      - we have much i am not able to think that broad regarding this data
#      - i have where orignal title and release year and genre like which movie is in released year group which gave more number of genre
#      -

# %% [markdown]
# ### Genre splitting

# %%
df['Genre'].unique()
# Out:
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Action, Adventure, Drama', 'Biography, Drama, History',
#        'Action, Adventure, Sci-Fi', 'Drama, Romance', 'Western',
#        'Action, Sci-Fi', 'Action, Adventure, Fantasy',
#        'Biography, Crime, Drama', 'Adventure, Drama, Sci-Fi',
#        'Crime, Drama, Mystery', 'Crime, Drama, Thriller', 'Drama, War',
#        'Crime, Drama, Fantasy', 'Animation, Adventure, Family',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Thriller',
#        'Drama, Family, Fantasy', 'Drama, Mystery, Sci-Fi',
#        'Adventure, Comedy, Sci-Fi', 'Crime, Mystery, Thriller',
#        'Animation, Adventure, Drama', 'Biography, Comedy, Drama',
#        'Biography, Drama, Music', 'Drama, Music',
#        'Horror, Mystery, Thriller', 'Drama, Romance, War',
#        'Animation, Drama, War', 'Comedy, Drama, Family',
#        'Action, Adventure', 'Drama, Western', 'Mystery, Thriller',
# ...

# %%
df['Genre'] =df['Genre'].str.split(', ')
df['Genre']
# Out:
# 0                           [Drama]
# 1                    [Crime, Drama]
# 2            [Action, Crime, Drama]
# 3                    [Crime, Drama]
# 4                    [Crime, Drama]
#                    ...
# 96           [Comedy, Crime, Drama]
# 97     [Adventure, Drama, Thriller]
# 98                        [Western]
# 99                          [Drama]
# 100      [Comedy, Musical, Romance]
# Name: Genre, Length: 98, dtype: object

# %%
exploded = df.explode('Genre')

# %%
df
# Out:
#     IMBD title ID               Original Title Release year  \
# 0       tt0111161     The Shawshank Redemption   1995-02-10
# 1       tt0068646                The Godfather   1972-09-21
# 2       tt0468569              The Dark Knight   2008-07-23
# 3       tt0071562       The Godfather: Part II   1975-09-25
# 4       tt0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...
# 96      tt0070735                    The Sting   1974-03-21
# 97      tt0082096                     Das Boot   1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹   1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin   2011-10-21
# 100     tt0045152          Singin' in the Rain   1953-02-05
#
#                             Genre  Duration       Country Content Rating  \
# 0                         [Drama]       142           USA              R
# 1                  [Crime, Drama]       175           USA              R
# ...

# %%
exploded.duplicated().sum()
# Out:
# np.int64(0)

# %%
exploded.groupby('Genre')['Income'].mean().sort_values(ascending=False)
# Out:
# Genre
# Action       7.484124e+08
# Adventure    6.471815e+08
# Animation    5.188281e+08
# Sci-Fi       4.591138e+08
# Fantasy      3.771832e+08
# Family       3.380902e+08
# Drama        2.737635e+08
# Crime        2.384383e+08
# Comedy       2.329131e+08
# History      1.958569e+08
# Biography    1.752603e+08
# Romance      1.745323e+08
# War          1.666063e+08
# Thriller     1.636948e+08
# Western      1.164334e+08
# Music        8.452792e+07
# Mystery      6.359618e+07
# Horror       6.221319e+07
# Musical      1.864182e+06
# Film-Noir    2.996450e+05
# Name: Income, dtype: float64

# %% [markdown]
# # Univariate :

# %% [markdown]
#  ### chech which year has many movies

# %%
df['Release year'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df['year'] = pd.to_datetime(df['Release year']).dt.year

# %%
df
# Out:
#     IMBD title ID               Original Title Release year  \
# 0       tt0111161     The Shawshank Redemption   1995-02-10
# 1       tt0068646                The Godfather   1972-09-21
# 2       tt0468569              The Dark Knight   2008-07-23
# 3       tt0071562       The Godfather: Part II   1975-09-25
# 4       tt0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...
# 96      tt0070735                    The Sting   1974-03-21
# 97      tt0082096                     Das Boot   1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹   1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin   2011-10-21
# 100     tt0045152          Singin' in the Rain   1953-02-05
#
#                             Genre  Duration       Country Content Rating  \
# 0                         [Drama]       142           USA              R
# 1                  [Crime, Drama]       175           USA              R
# ...

# %%
df['year'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df['year'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
df['decade'] = (df['year'] // 10) * 10

# %%
df['decade'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='decade'>

# %% [markdown]
# Insights : In 2000s there are many movies and even in 1990 gradually it ihas decreased

# %%
df.groupby('decade').size().plot(kind='bar') # other way for same plot
# Out:
# <Axes: xlabel='decade'>

# %% [markdown]
# ### WHich genre are many

# %%
exploded['Genre'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Genre'>

# %% [markdown]
# Insights : Drama has many movies

# %% [markdown]
# ### Country which country has many movies

# %%
df['Country'].unique()
# Out:
# array(['USA', 'New Zealand', 'UK', 'Italy', 'Brazil', 'Japan',
#        'South Korea', 'France', 'Germany', 'India', 'Denmark',
#        'West Germany', 'Iran'], dtype=object)

# %%
df['Country'].value_counts().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# Insights : USA has many movies

# %% [markdown]
# ### WHich is the director made many movies

# %%
df['Director'].value_counts().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan     6
# Stanley Kubrick       5
# Quentin Tarantino     4
# Alfred Hitchcock      4
# Sergio Leone          4
#                      ..
# Chan-wook Park        1
# Lee Unkrich           1
# Jean-Pierre Jeunet    1
# David Lean            1
# Stanley Donen         1
# Name: count, Length: 63, dtype: int64

# %%
df['Director'].value_counts().sort_values(ascending=False).plot(kind='bar' , figsize=(15,12))
# Out:
# <Axes: xlabel='Director'>

# %% [markdown]
# # Bivarirate :

# %% [markdown]
# ### Which year genrated more income

# %%
year_income = df.groupby('year')['Income'].mean().sort_values(ascending=False)

year_income.plot(kind='bar' , figsize=(12,6))
# Out:
# <Axes: xlabel='year'>

# %%
# With the help matplotlib library
plt.figure(figsize=(12,6))
plt.bar(year_income.index.astype(str),year_income.values , color = 'red')
plt.xticks(rotation = 90)
plt.xlabel('Year')
plt.ylabel('Income')
plt.legend()
plt.show()
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_31417/3535470215.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Which genre created more income

# %%
genre_income = exploded.groupby('Genre')['Income'].mean().sort_values(ascending=False)
genre_income.plot(kind='line')
# Out:
# <Axes: xlabel='Genre'>

# %%
genre_income.plot(kind='bar')
# Out:
# <Axes: xlabel='Genre'>

# %%
plt.figure(figsize=(18,9))
plt.bar(genre_income.index , genre_income.values , color = 'Orange')
plt.margins(x = 0)
plt.xlabel("Genre")
plt.ylabel("Income")
plt.show()

# %% [markdown]
# Insights : Action movie has generated more number of income

# %% [markdown]
# ### which genre has more duration

# %%
genre_duration = exploded.groupby('Genre')['Duration'].agg(['mean','count'])
genre_duration.plot(kind='bar')
# Out:
# <Axes: xlabel='Genre'>

# %%
x = np.arange(len(genre_duration))
width = 0.4
plt.figure(figsize=(18,5))
plt.bar(x + width/2 , genre_duration['mean'],width, label = 'Mean Duration', color = 'red')
plt.bar(x + width/2 , genre_duration['count'],width,label ="Count Duration", color = 'blue')
plt.margins(x = 0)
plt.xticks(x,genre_duration.index)
plt.xlabel("Genre")
plt.ylabel("Duration")
plt.legend()
plt.show()

# %% [markdown]
# Insight: Biography movies have the highest average duration (157 mins, based on only 7 movies — small sample). Drama is the most frequent genre by far (65 movies), though its average duration is lower (140 mins).

# %% [markdown]
# ### is there any relation between Duration and Income

# %%
income_duration = exploded.groupby('Duration')['Income'].mean()
income_duration.plot(kind='line')
# Out:
# <Axes: xlabel='Duration'>

# %%
plt.figure(figsize=(18,8))
plt.bar(income_duration.index,income_duration.values , color = 'skyblue')
# Out:
# <BarContainer object of 64 artists>

# %%
plt.figure(figsize=(18,8))
plt.scatter(df['Duration'], df['Income'] , color = 'skyblue')
plt.xlabel('Duration of Movie(mins)')
plt.ylabel('Income of Movie')
# Out:
# Text(0, 0.5, 'Income of Movie')

# %%
df['Duration'].corr(df['Income'])
# Out:
# np.float64(0.21472776575268998)

# %% [markdown]
# Insights : There is week relation between teh Duration and Income so better not look into it

# %% [markdown]
# ### which director created more income

# %%
director_Income = df.groupby('Director')['Income'].mean().sort_values(ascending=False)
director_Income.plot(kind='bar')
# Out:
# <Axes: xlabel='Director'>

# %%
top_director = director_Income.head(15)
plt.figure(figsize=(18,5))
plt.bar(top_director.index,top_director.values)
plt.xticks(rotation = 90)
plt.title("Top 15 Directors Income of movies")
plt.xlabel("Director")
plt.ylabel("Income")
plt.show()

# %%
df[df['Director'] == 'Anthony Russo, Joe Russo']
# Out:
#    IMBD title ID          Original Title Release year  \
# 56     tt4154756  Avengers: Infinity War   2018-04-25
# 58     tt4154796       Avengers: Endgame   2019-04-24
#
#                           Genre  Duration Country Content Rating  \
# 56  [Action, Adventure, Sci-Fi]       149     USA      Not Rated
# 58   [Action, Adventure, Drama]       181     USA      Not Rated
#
#                     Director      Income   Votes  Score  year  decade
# 56  Anthony Russo, Joe Russo  2048359754  796486    8.2  2018    2010
# 58  Anthony Russo, Joe Russo  2797800564  754786    8.2  2019    2010

# %% [markdown]
#  Insights : Anthony Russo and Jow Russo have generated more income from the movies

# %% [markdown]
# ### Did content rating effect the Income

# %%
rating_Income = df.groupby('Content Rating')['Income'].mean().sort_values(ascending=False)
rating_Income.plot(kind='bar')
# Out:
# <Axes: xlabel='Content Rating'>

# %%
plt.figure(figsize=(18,5))
plt.bar(rating_Income.index,rating_Income.values, color = 'grey')
plt.xlabel("Content - Rating")
plt.ylabel("Income")
plt.show()

# %%
df['Content Rating'].value_counts()
# Out:
# Content Rating
# R            43
# Not Rated    24
# PG-13        12
# PG           11
# G             6
# Approved      1
# Unrated       1
# Name: count, dtype: int64

# %% [markdown]
# Insights : Pg - 13 has made more income

# %% [markdown]
# ### Which country created more number of income

# %%
country_income = df.groupby('Country')['Income'].mean().sort_values(ascending=False)
country_income.plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
plt.figure(figsize=(18,5))
plt.bar(country_income.index, country_income.values, color = 'black')
plt.xlabel("Country")
plt.ylabel("Income")
plt.show()

# %%
df[df['Country'] == 'New Zealand']
# Out:
#    IMBD title ID                                     Original Title  \
# 5      tt0167260      The Lord of the Rings: The Return of the King
# 11     tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 15     tt0167261              The Lord of the Rings: The Two Towers
#
#    Release year                       Genre  Duration      Country  \
# 5    2004-02-22  [Action, Adventure, Drama]       201  New Zealand
# 11   2002-01-18  [Action, Adventure, Drama]       178  New Zealand
# 15   2003-01-16  [Action, Adventure, Drama]       179  New Zealand
#
#    Content Rating       Director      Income    Votes  Score  year  decade
# 5           PG-13  Peter Jackson  1142271098  1604280    8.9  2004    2000
# 11          PG-13  Peter Jackson   887934303  1619920    8.8  2002    2000
# 15          PG-13  Peter Jackson   951227416  1449778    8.7  2003    2000

# %% [markdown]
# Insight : We can't generalize that Newzland is highest as it has only 3 movies that makes things go uncertain

# %% [markdown]
# ### Which movie has more votes

# %%
top_votes = df[["Original Title" , "Votes"]].sort_values('Votes' , ascending=False)
top_10 = top_votes.head(15)

# %%
plt.figure(figsize=(18,5))
plt.barh(top_10["Original Title"], top_10["Votes"], color = 'black')
plt.xticks(rotation = 90)
plt.xlabel("Country")
plt.ylabel("Income")
plt.gca().invert_yaxis()
plt.show()
