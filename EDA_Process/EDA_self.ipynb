# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Churn_Modelling_EDA.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df = data.copy()

# %%
df = df.drop(columns=['customerID'])
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# Data exploration

# %% [markdown]
# Univariate Analysis

# %%
sns.countplot(data= df , x = 'gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df['gender'].value_counts()/len(df) * 100
# Out:
# gender
# Male      50.47565
# Female    49.52435
# Name: count, dtype: float64

# %% [markdown]
# Insights  :In Gender there is no such difference like both are paralell

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
sns.countplot(data=df , x = 'Partner')
plt.show()

# %% [markdown]
# Insights : there are 48 percent of them are Partners who are together and 51 percent of them are who are not

# %%
sns.histplot(data=df, x='MonthlyCharges', kde=True)
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Count'>

# %% [markdown]
# ## Bivariate
# - Feature       ↔ Churn
# - Contract      ↔ Churn
# - tenure        ↔ Churn
# - MonthlyCharges ↔ Churn
# - PaymentMethod ↔ Churn
# - InternetService ↔ Churn
# - Partner       ↔ Churn
# - SeniorCitizen ↔ Churn

# %%
df1_target_1 = df[df['Churn'] == 1]
df1_target_0 = df[df['Churn'] == 0]
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
for i , prediction in enumerate(df.drop(columns=['Churn' ,'TotalCharges' , 'MonthlyCharges'])):
    plt.figure(i)
    sns.countplot(data= df, x = prediction , hue='Churn')

# %%
pd.crosstab(df['SeniorCitizen'], df['Churn'], normalize='index') * 100
# Out:
# Churn                 No        Yes
# SeniorCitizen
# 0              76.393832  23.606168
# 1              58.318739  41.681261

# %%
pd.crosstab(df['Partner'], df['Churn'], normalize='index') * 100
# Out:
# Churn           No        Yes
# Partner
# No       67.042021  32.957979
# Yes      80.335097  19.664903

# %%
pd.crosstab(df['MultipleLines'], df['Churn'], normalize='index') * 100
# Out:
# Churn                    No        Yes
# MultipleLines
# No                74.955752  25.044248
# No phone service  75.073314  24.926686
# Yes               71.390104  28.609896

# %%
pd.crosstab(df['OnlineSecurity'], df['Churn'], normalize='index') * 100
# Out:
# Churn                       No        Yes
# OnlineSecurity
# No                   58.233276  41.766724
# No internet service  92.595020   7.404980
# Yes                  85.388806  14.611194

# %%
pd.crosstab(df['PaymentMethod'], df['Churn'], normalize='index') * 100
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.290155  16.709845
# Credit card (automatic)    84.756899  15.243101
# Electronic check           54.714588  45.285412
# Mailed check               80.893300  19.106700

# %%
pd.crosstab(df['Contract'], df['InternetService'])
# Out:
# InternetService   DSL  Fiber optic   No
# Contract
# Month-to-month   1223         2128  524
# One year          570          539  364
# Two year          628          429  638
